# %%
import os
import openai
import sys
from langchain.chat_models import ChatOpenAI
sys.path.append('../..')


from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.environ['OPENAI_API_KEY']

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import MongoDBAtlasVectorSearch
from langchain.document_loaders import PyPDFLoader

loader = PyPDFLoader("files/us_constitution.pdf")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

embeddings = OpenAIEmbeddings()

# %%
from pymongo import MongoClient

# initialize MongoDB python client
client = MongoClient("mongodb://192.168.5.76:27017")

db_name = "langchain_db"
collection_name = "langchain_col"
collection = client[db_name][collection_name]
index_name = "langchain_demo"

# insert the documents in MongoDB Atlas with their embedding
docsearch = MongoDBAtlasVectorSearch.from_documents(
    docs, embeddings, collection=collection, index_name=index_name
)

# perform a similarity search between the embedding of the query and the embeddings of the documents
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(query)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 from pymongo import MongoClient
#       3 # initialize MongoDB python client
# ----> 4 client = MongoClient(MONGODB_ATLAS_CLUSTER_URI)
#       6 db_name = "langchain_db"
#       7 collection_name = "langchain_col"
#
# NameError: name 'MONGODB_ATLAS_CLUSTER_URI' is not defined

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(query)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[13], line 2
#       1 query = "What did the president say about Ketanji Brown Jackson"
# ----> 2 docs = docsearch.similarity_search(query)
#
# File ~\llm\llm-env\Lib\site-packages\langchain\vectorstores\mongodb_atlas.py:246, in MongoDBAtlasVectorSearch.similarity_search(self, query, k, pre_filter, post_filter_pipeline, **kwargs)
#     218 def similarity_search(
#     219     self,
#     220     query: str,
#    (...)
#     224     **kwargs: Any,
#     225 ) -> List[Document]:
#     226     """Return MongoDB documents most similar to query.
#     227
#     228     Use the knnBeta Operator available in MongoDB Atlas Search
#    (...)
#     244         List of Documents most similar to the query and score for each
#     245     """
# --> 246     docs_and_scores = self.similarity_search_with_score(
#     247         query,
#     248         k=k,
#     249         pre_filter=pre_filter,
#     250         post_filter_pipeline=post_filter_pipeline,
#     251     )
#     252     return [doc for doc, _ in docs_and_scores]
#
# File ~\llm\llm-env\Lib\site-packages\langchain\vectorstores\mongodb_atlas.py:210, in MongoDBAtlasVectorSearch.similarity_search_with_score(self, query, k, pre_filter, post_filter_pipeline)
#     189 """Return MongoDB documents most similar to query, along with scores.
#     190
#     191 Use the knnBeta Operator available in MongoDB Atlas Search
#    (...)
#     207     List of Documents most similar to the query and score for each
#     208 """
#     209 embedding = self._embedding.embed_query(query)
# --> 210 docs = self._similarity_search_with_score(
#     211     embedding,
#     212     k=k,
#     213     pre_filter=pre_filter,
#     214     post_filter_pipeline=post_filter_pipeline,
#     215 )
#     216 return docs
#
# File ~\llm\llm-env\Lib\site-packages\langchain\vectorstores\mongodb_atlas.py:173, in MongoDBAtlasVectorSearch._similarity_search_with_score(self, embedding, k, pre_filter, post_filter_pipeline)
#     171 if post_filter_pipeline is not None:
#     172     pipeline.extend(post_filter_pipeline)
# --> 173 cursor = self._collection.aggregate(pipeline)  # type: ignore[arg-type]
#     174 docs = []
#     175 for res in cursor:
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\collection.py:2722, in Collection.aggregate(self, pipeline, session, let, comment, **kwargs)
#    2644 """Perform an aggregation using the aggregation framework on this
#    2645 collection.
#    2646
#    (...)
#    2719     https://mongodb.com/docs/manual/reference/command/aggregate
#    2720 """
#    2721 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2722     return self._aggregate(
#    2723         _CollectionAggregationCommand,
#    2724         pipeline,
#    2725         CommandCursor,
#    2726         session=s,
#    2727         explicit_session=session is not None,
#    2728         let=let,
#    2729         comment=comment,
#    2730         **kwargs,
#    2731     )
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\collection.py:2629, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, let, comment, **kwargs)
#    2618     kwargs["comment"] = comment
#    2619 cmd = aggregation_command(
#    2620     self,
#    2621     cursor_class,
#    (...)
#    2626     user_fields={"cursor": {"firstBatch": 1}},
#    2627 )
# -> 2629 return self.__database.client._retryable_read(
#    2630     cmd.get_cursor,
#    2631     cmd.get_read_preference(session),  # type: ignore[arg-type]
#    2632     session,
#    2633     retryable=not cmd._performs_write,
#    2634 )
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\mongo_client.py:1535, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1533             assert last_error is not None
#    1534             raise last_error
# -> 1535         return func(session, server, conn, read_pref)
#    1536 except ServerSelectionTimeoutError:
#    1537     if retrying:
#    1538         # The application may think the write was never attempted
#    1539         # if we raise ServerSelectionTimeoutError on the retry
#    1540         # attempt. Raise the original exception instead.
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\aggregation.py:164, in _AggregationCommand.get_cursor(self, session, server, conn, read_preference)
#     161     write_concern = None
#     163 # Run command.
# --> 164 result = conn.command(
#     165     self._database.name,
#     166     cmd,
#     167     read_preference,
#     168     self._target.codec_options,
#     169     parse_write_concern_error=True,
#     170     read_concern=read_concern,
#     171     write_concern=write_concern,
#     172     collation=self._collation,
#     173     session=session,
#     174     client=self._database.client,
#     175     user_fields=self._user_fields,
#     176 )
#     178 if self._result_processor:
#     179     self._result_processor(result, conn)
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\helpers.py:315, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     312 from pymongo.pool import Connection
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except OperationFailure as exc:
#     317     if no_reauth:
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\pool.py:932, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     930     self._raise_if_not_writable(unacknowledged)
#     931 try:
# --> 932     return command(
#     933         self,
#     934         dbname,
#     935         spec,
#     936         self.is_mongos,
#     937         read_preference,
#     938         codec_options,
#     939         session,
#     940         client,
#     941         check,
#     942         allowable_errors,
#     943         self.address,
#     944         listeners,
#     945         self.max_bson_size,
#     946         read_concern,
#     947         parse_write_concern_error=parse_write_concern_error,
#     948         collation=collation,
#     949         compression_ctx=self.compression_context,
#     950         use_op_msg=self.op_msg_enabled,
#     951         unacknowledged=unacknowledged,
#     952         user_fields=user_fields,
#     953         exhaust_allowed=exhaust_allowed,
#     954         write_concern=write_concern,
#     955     )
#     956 except (OperationFailure, NotPrimaryError):
#     957     raise
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\network.py:191, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     189             client._process_response(response_doc, session)
#     190         if check:
# --> 191             helpers._check_command_response(
#     192                 response_doc,
#     193                 conn.max_wire_version,
#     194                 allowable_errors,
#     195                 parse_write_concern_error=parse_write_concern_error,
#     196             )
#     197 except Exception as exc:
#     198     if publish:
#
# File ~\llm\llm-env\Lib\site-packages\pymongo\helpers.py:223, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     220 elif code == 43:
#     221     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 223 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Unrecognized pipeline stage name: '$search', full error: {'ok': 0.0, 'errmsg': "Unrecognized pipeline stage name: '$search'", 'code': 40324, 'codeName': 'Location40324', '$clusterTime': {'clusterTime': Timestamp(1694694011, 3), 'signature': {'hash': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'keyId': 0}}, 'operationTime': Timestamp(1694693960, 42)}
